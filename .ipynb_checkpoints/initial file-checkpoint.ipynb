# %%
import pandas as pd

# %%
csv_path = "100_point_wine.csv"
top_100_df = pd.read_csv(csv_path)
print(top_100_df.dtypes)

top_100_new_head = top_100_df.set_index('ID')
top_100_new_head.head()
# Out:
# ID                int64
# rating            int64
# winery           object
# category         object
# varietal         object
# title            object
# region           object
# subregion        object
# subsubregion     object
# country          object
# price             int64
# vintage         float64
# dtype: object
#       rating                winery     category         varietal  \
# ID
# 5933     100  W. &amp; J. Graham's  Port/Sherry             Port
# 6126     100            Sattlerhof      Dessert  Sauvignon Blanc
# 6127     100               Kracher      Dessert   Muscat Ottonel
# 6128     100               Kracher      Dessert        Scheurebe
# 6129     100             Pol Roger    Sparkling  Champagne Blend
#
#                                                   title          region  \
# ID
# 5933  100pointsW. &amp; J. Graham's 2016 The Stone T...            Port
# 6126  Sattlerhof 2013 Trockenbeerenauslese Sauvignon...  SÃ¼dsteiermark
# ...

# %%
top_100_new_head.to_csv('100_point_wine2.csv')
